# %%
import pandas as pd
import matplotlib.pyplot as plt

# %run carolinaDataChallenge.ipynb
# %run newAmishi.ipynb 

fig, ax = plt.subplots(figsize= (25, 15))

df_finished_rvbi.drop(columns=[df_finished_rvbi.columns[0]]).iloc[-1] / 2200
ax.bar(
    x=df_finished_rvbi.drop(columns=[df_finished_rvbi.columns[0]]).columns, # [[range(2012:2024)]]
    height=df_finished_rvbi.drop(columns=[df_finished_rvbi.columns[0]]).iloc[1], # [range(2012:2024)] 
    width=df_finished_rvbi.drop(columns=[df_finished_rvbi.columns[0]]).iloc[-1] / 2200,
    #color=df_finished_rvbi.drop(columns=[df_finished_rvbi.columns[0]]).iloc[-1] / 400,
    # x=df_finished_eco.drop(columns=[df_finished_eco.columns[0]]).columns, 
    # height=df_finished_eco.drop(columns=[df_finished_eco.columns[0]]).iloc[0],
    color='skyblue',
    edgecolor="black"
)

private

# poo
# Out:
#     Year  Annual number of objects launched into outer space
# 0   2012                                                 33
# 1   2013                                                 80
# 2   2014                                                 95
# 3   2015                                                104
# 4   2016                                                105
# 5   2017                                                286
# 6   2018                                                190
# 7   2019                                                362
# 8   2020                                                984
# 9   2021                                               1232
# 10  2022                                               1939
# 11  2023                                               2234
#     Year Real Value Added by Industry (millions)  \
# 0   2012                                  79,861
# 1   2013                                   89170
# ...

# %%
df_finished_rvbi.drop(columns=[df_finished_rvbi.columns[0]])
# Out:
#        2012     2013     2014     2015     2016     2017     2018      2019  \
# 0   101,966  111,559  113,173  121,868  123,054  122,183  119,387   122,860
# 1    79,861   89,170   90,495   98,536   99,506   98,699   95,196    96,575
# 2         …        …        …        …        …        …        …         …
# 3         …        …        …        …        …        …        …         …
# 4         …        …        …        …        …        …        …         …
# ..      ...      ...      ...      ...      ...      ...      ...       ...
# 94    2,022    1,823    1,742    1,884    1,799    1,679    1,816     2,001
# 95    2,022    1,823    1,742    1,884    1,799    1,679    1,816     2,001
# 96        0        0        0        0        0        0        0         0
# 97  74,773   81,343   83,765   90,879   95,154   95,734   96,788   101,708
# 98       33       80       95      104      105      286      190       362
#
#        2020     2021      2022      2023
# ...

# %%
private["Proportion_Increase"] = private["Real Gross Output by Industry (millions)"].pct_change()

private
import numpy as np

a, b, N = 0, np.pi, 1000


def f(x):
    return np.sin(x)


x_random = np.random.uniform(a, b, N)
estimate = (b - a) * np.mean(f(x_random))

print(f"Monte Carlo Estimate: {estimate:.4f}")
# Out:
# Monte Carlo Estimate: 1.9429
