# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
eco = pd.read_csv('eco.csv')
eco.head()
# Out:
#                       Economy Employment by Industry 2012 2013 2014 2015 2016  \
# 0                 Space economy, private industries1  433  432  426  424  411
# 1          Agriculture, forestry, fishing, and hu...    …    …    …    …    …
# 2                                              Farms    …    …    …    …    …
# 3              Forestry, fishing, and related act...    …    …    …    …    …
# 4                                             Mining    0    0    0    0    0
#
#   2017 2018 2019 2020 2021 2022 2023
# 0  399  387  390  365  351  361  373
# 1    …    …    …    …    …    …    …
# 2    …    …    …    …    …    …    …
# 3    …    …    …    …    …    …    …
# 4    0    0    0    0    0    0    0

# %%
rva = pd.read_csv('rva.csv')
rva2 = rva.set_index(rva['Real Value by Industry']).drop(columns = ['Real Value by Industry'])
rva2 = rva2.T
rva2= rva2.reset_index()
rva2.head()
# Out:
# Real Value by Industry index Space economy1     Private industries  \
# 0                       2012        101,966                 79,861
# 1                       2013        111,559                 89,170
# 2                       2014        113,173                 90,495
# 3                       2015        121,868                 98,536
# 4                       2016        123,054                 99,506
#
# Real Value by Industry         Agriculture, forestry, fishing, and hunting  \
# 0                                                                       …
# 1                                                                       …
# 2                                                                       …
# 3                                                                       …
# 4                                                                       …
#
# Real Value by Industry             Farms  \
# 0                                      …
# ...
